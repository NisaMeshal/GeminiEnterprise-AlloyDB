# %% [markdown]
# # Gemini Enterprise + AlloyDB
#
# This notebook provides the setup to connect Gemini Enterprise and AlloyDB to ground responses with live data stored on AlloyDB.
#
# References
# * [AlloyDB AI NL2SQL](https://docs.cloud.google.com/alloydb/docs/ai/generate-sql-queries-natural-language)
# * [Gemini Enterprise AlloyDB Connector](https://docs.cloud.google.com/gemini/enterprise/docs/connect-alloydb-data)
#
# Note: Some features may be in preview. Please ensure that features are enabled in your project.
#
# ### Requirements
# * An AlloyDB for PostgreSQL instance
# * Gemini Enterprise application (we will be creating a datastore/connector for AlloyDB and you can connect it to any application)
#
# ### Define Variables
# Update the following variables to match your environment

# %%
project_id = "your-project-id"
region = "your-region"
alloydb_cluster = "your-alloydb-cluster"
alloydb_instance = "your-alloydb-instance"  
alloydb_database = "your-alloydb-database"
alloydb_password = input("Please provide a password to be used for 'postgres' database user: ")
